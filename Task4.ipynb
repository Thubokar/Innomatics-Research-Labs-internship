# %% [markdown]
# <a href="https://colab.research.google.com/github/Thubokar/Innomatics-Research-Labs-internship/blob/main/Task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# List of messages
messages = ["Hi", "Welcome to the platform", "OK"]

# Analyze each message
for msg in messages:
    length = len(msg)  # Get length of the message
    print(f"Message: '{msg}' | Length: {length}", end="")

    # Flag messages longer than 10 characters
    if length > 10:
        print(" -> Long message")
    else:
        print(" -> Short message")
# Out:
# Message: 'Hi' | Length: 2 -> Short message
# Message: 'Welcome to the platform' | Length: 23 -> Long message
# Message: 'OK' | Length: 2 -> Short message
